# %%
import pandas as pd

# %%
df = pd.read_csv("rois-france-avec-dates.csv")

# %%
df
# Out:
#                        nom           dateOfBirth  \
# 0      Louis VII de France  1120-01-01T00:00:00Z
# 1     Louis VIII de France  1187-09-12T00:00:00Z
# 2    Charles VII de France  1403-03-03T00:00:00Z
# 3             Hugues Capet  0940-01-01T00:00:00Z
# 4       Louis VI de France  1081-12-07T00:00:00Z
# 5                 Henri II  1519-04-10T00:00:00Z
# 6             Charles VIII  1470-07-09T00:00:00Z
# 7               Charles VI  1368-12-11T00:00:00Z
# 8      Henri Ier de France  1008-05-04T00:00:00Z
# 9      Charles V de France  1338-01-29T00:00:00Z
# 10   Philippe VI de France  1293-11-24T00:00:00Z
# 11    Charles IV de France  1294-06-25T00:00:00Z
# 12     Robert II de France  0972-04-01T00:00:00Z
# 13              Charles IX  1550-07-07T00:00:00Z
# 14   Philippe IV de France  1268-01-01T00:00:00Z
# 15             François II  1544-01-29T00:00:00Z
# 16              Louis XIII  1601-09-27T00:00:00Z
# 17                Henri IV  1553-12-23T00:00:00Z
# ...

# %%
df.shape
# Out:
# (33, 16)

# %%
df[df["startYear"] > 1567].shape
# Out:
# (8, 16)
