# %%
import pandas as pd

# %%
df = pd.read_csv('../csv/postgres/personnage.csv')

# %%
df = df.drop(columns=['prod', 'cat'])

# %%
df['cat'] = "roi"

# %%
df['prod'] = 0

# %%
df.to_csv("../csv/postgres/personnage.csv", index=False)

# %%
df
# Out:
#      wikiid                    nom dateofbirth placeofbirthlabel dateofdeath  \
# 0   Q134259    Louis VII de France  1120-01-01             Paris  1180-09-25
# 1   Q165284   Louis VIII de France  1187-09-12             Paris  1226-11-15
# 2   Q109223          Childebert IV  0678-01-01       t1766657890  0711-04-18
# 3   Q316869             Thierry II         NaN               NaN         NaN
# 4   Q133372  Charles VII de France  1403-03-03             Paris  1461-07-31
# ..      ...                    ...         ...               ...         ...
# 79  Q193658    Louis IV d'Outremer         NaN              Laon         NaN
# 80  Q242832               Lothaire         NaN              Laon  0986-03-02
# 81  Q205289                Louis V         NaN               NaN  0987-05-22
# 82    Q8384      Louis X de France  1289-10-04             Paris  1316-06-05
# 83    Q8404     Jean Ier de France  1316-11-15             Paris  1316-11-20
#
# ...
