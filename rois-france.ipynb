# %% [markdown]
# # Notebook requêtant wikidata en SPARQL

# %% [markdown]
# Imports

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import numpy as np
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# ### 1) Récupération de tous les rois de France

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT ?item ?itemLabel (GROUP_CONCAT(DISTINCT ?spouseLabel;separator=", ") AS ?spouses) (GROUP_CONCAT(DISTINCT ?mannerOfDeathLabel;separator=", ") AS ?mannersOfDeath) 
# ?dateOfBirth ?placeOfBirthLabel ?dateOfDeath ?placeOfDeathLabel ?placeOfBurialLabel ?fatherLabel ?motherLabel ?conflictLabel ?startTime ?endTime

WHERE
{
{?item wdt:P31 wd:Q5 .} 
{?item wdt:P39 wd:Q18384454 .} UNION {?item wdt:P39 wd:Q22923081} UNION {?item wdt:P39 wd:Q3439798}
{?item wdt:P569 ?dateOfBirth} UNION {MINUS {?item wdt:P569 ?dateOfBirth}}
{?item wdt:P19 ?placeOfBirth} UNION {MINUS {?item wdt:P19 ?placeOfBirth}}
{?item wdt:P570 ?dateOfDeath} UNION {MINUS {?item wdt:P570 ?dateOfDeath}}
{?item wdt:P19 ?placeOfDeath} UNION {MINUS {?item wdt:P19 ?placeOfDeath}}
{?item wdt:P509 ?mannerOfDeath} UNION {MINUS {?item wdt:P509 ?mannerOfDeath}}
{?item wdt:P119 ?placeOfBurial} UNION {MINUS {?item wdt:P119 ?placeOfBurial}}
{?item wdt:P22 ?father} UNION {MINUS {?item wdt:P22 ?father}}
{?item wdt:P25 ?mother} UNION {MINUS {?item wdt:P25 ?mother}}
{?item wdt:P26 ?spouse} UNION {MINUS {?item wdt:P26 ?spouse}}
{?item wdt:P607 ?conflict} UNION {MINUS {?item wdt:P607 ?conflict}}
# ?item p:P39 ?positionHeld.
{?positionHeld pq:P580 ?startTime.} UNION {MINUS {?positionHeld pq:P580 ?startTime.}}
{?positionHeld pq:P582 ?endTime.} UNION {MINUS {?positionHeld pq:P582 ?endTime.}}
  
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr" .
                         # ?item rdfs:label ?itemLabel .
                         # ?placeOfBirth rdfs:label ?placeOfBirthLabel .
                         # ?placeOfDeath rdfs:label ?placeOfDeathLabel .
                         # ?mannerOfDeath rdfs:label ?mannerOfDeathLabel .
                         # ?placeOfBurial rdfs:label ?placeOfBurialLabel .
                         # ?father rdfs:label ?fatherLabel .
                         # ?mother rdfs:label ?motherLabel .
                         # ?spouse rdfs:label ?spouseLabel .}
}GROUP BY ?item ?itemLabel ?dateOfBirth ?placeOfBirthLabel ?dateOfDeath ?placeOfDeathLabel ?placeOfBurialLabel ?fatherLabel ?motherLabel ?conflictLabel ?startTime ?endTime

""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results
# Out:
# {'head': {'vars': ['item',
#    'itemLabel',
#    'spouses',
#    'mannersOfDeath',
#    'dateOfBirth',
#    'placeOfBirthLabel',
#    'dateOfDeath',
#    'placeOfDeathLabel',
#    'placeOfBurialLabel',
#    'fatherLabel',
#    'motherLabel',
#    'conflictLabel',
#    'startTime',
#    'endTime']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134259'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Louis VII de France'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '1120-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Paris'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '1180-09-25T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Paris'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'basilique Saint-Denis'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': '
{'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0814-02-01T00:00:00Z'},
#     'spouses': {'type': 'literal',
#      'value': 'Himiltrude, Désirée de Lombardie, Luitgarde, Fastrade, Hildegarde'},
#     'mannersOfDeath': {'type': 'literal', 'value': 'maladie'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q3044'},
# ...
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0548-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1774564747'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Thierry Ier'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Ne'},
#     'spouses': {'type': 'literal', 'value': 'Deoteria, Wisigarde'},
#     'mannersOfDeath': {'type': 'literal', 'value': 'attaque animale'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q304688'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Childebert III l'Adopté"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0650-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1777639808'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0662-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1777639808'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Grimoald Ier'},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q309946'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Sigebert Ier'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0535-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1777669362'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0575-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1777669362'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Clotaire Ier'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Ingonde'},
#     'spouses': {'type': 'literal', 'value': 'Brunehaut'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q546611'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Charles l'Enfant"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0847-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Francfort-sur-le-Main'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0866-10-03T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Francfort-sur-le-Main'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Centre-Val de Loire'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Charles II le Chauve'},
#     'motherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Ermentrude d'Orléans"},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q713506'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Mérogaise'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0300-01-01T00:00:00Z'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0306-01-01T00:00:00Z'},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q43974'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Louis le Pieux'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0778-04-20T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Chasseneuil-du-Poitou'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0840-06-24T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Chasseneuil-du-Poitou'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'abbaye de Saint-Arnould'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Charlemagne'},
#     'motherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Hildegarde'},
#     'spouses': {'type': 'literal',
#      'value': 'Ermengarde de Hesbaye, Judith de Bavière'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q73806'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Boson de Provence'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0844-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1545842460'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0887-01-15T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1545842460'},
#     'fatherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Bivin'},
#     'motherLabel': {'type': 'literal', 'value': 'Q61717067'},
#     'spouses': {'type': 'literal', 'value': 'Ermengarde'},
#     'mannersOfDeath': {'type': 'literal', 'value': 'maladie'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q150620'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Henri Ier'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0876-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Saxe'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0936-07-07T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Saxe'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'abbaye de Quedlinbourg'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Otton Ier de Saxe'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Hedwige'},
#     'spouses': {'type': 'literal',
#      'value': 'Q3555663, Mathilde de Ringelheim'},
#     'mannersOfDeath': {'type': 'literal',
#      'value': 'accident vasculaire cérébral'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q233534'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Galswinthe'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0540-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Tolède'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0568-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Tolède'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Athanagilde Ier'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Goswinthe'},
#     'spouses': {'type': 'literal', 'value': 'Chilpéric Ier'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q237750'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Bathilde'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0626-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1774520309'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0680-01-30T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1774520309'},
#     'spouses': {'type': 'literal', 'value': 'Clovis II'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q295086'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Gontran'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0532-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Soissons'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0593-03-30T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Soissons'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Clotaire Ier'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Ingonde'},
#     'spouses': {'type': 'literal', 'value': 'Marcatrude, Austregilde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q295086'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Gontran'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0532-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Soissons'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0592-03-30T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Soissons'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Clotaire Ier'},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Ingonde'},
#     'spouses': {'type': 'literal', 'value': 'Marcatrude, Austregilde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q333319'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Bernard d'Italie"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0797-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1780316954'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0818-04-21T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Hauts-de-France'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Lombardie'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Pépin d'Italie"},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chrotais'},
#     'spouses': {'type': 'literal', 'value': 'Cunégonde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q333319'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Bernard d'Italie"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0797-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1780316954'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0818-04-21T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1780316954'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Lombardie'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Pépin d'Italie"},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chrotais'},
#     'spouses': {'type': 'literal', 'value': 'Cunégonde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q333319'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Bernard d'Italie"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0797-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Hauts-de-France'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0818-04-21T00:00:00Z'},
#     'placeOfDeathLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Hauts-de-France'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Lombardie'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Pépin d'Italie"},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chrotais'},
#     'spouses': {'type': 'literal', 'value': 'Cunégonde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q333319'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Bernard d'Italie"},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0797-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Hauts-de-France'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0818-04-21T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1780316954'},
#     'placeOfBurialLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Lombardie'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': "Pépin d'Italie"},
#     'motherLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chrotais'},
#     'spouses': {'type': 'literal', 'value': 'Cunégonde'},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1259648'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chilpéric'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0700-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1394245358'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0632-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1394245358'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Caribert II'},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}},
#    {'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1259648'},
#     'itemLabel': {'xml:lang': 'fr', 'type': 'literal', 'value': 'Chilpéric'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0630-01-01T00:00:00Z'},
#     'placeOfBirthLabel': {'type': 'literal', 'value': 't1394245358'},
#     'dateOfDeath': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '0632-01-01T00:00:00Z'},
#     'placeOfDeathLabel': {'type': 'literal', 'value': 't1394245358'},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Caribert II'},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}}]}}

# %%
rois = []
for r in results['results']['bindings']:
    roi = {}
    if("itemLabel" in r):
        roi['nom'] = r['itemLabel']['value']
    if("dateOfBirth" in r):
        roi['dateOfBirth'] = r['dateOfBirth']['value']
    if("placeOfBirthLabel" in r):
        roi['placeOfBirthLabel'] = r['placeOfBirthLabel']['value']
    if("dateOfDeath" in r):
        roi['dateOfDeath'] = r['dateOfDeath']['value']
    if("placeOfDeathLabel" in r):
        roi['placeOfDeathLabel'] = r['placeOfDeathLabel']['value']
    if("mannerOfDeathLabel" in r):
        roi['mannerOfDeathLabel'] = r['mannerOfDeathLabel']['value']
    if("placeOfBurialLabel" in r):
        roi['placeOfBurialLabel'] = r['placeOfBurialLabel']['value']
    if("fatherLabel" in r):
        roi['fatherLabel'] = r['fatherLabel']['value']
    if("motherLabel" in r):
        roi['motherLabel'] = r['motherLabel']['value']
    if("spouses" in r):
        roi['spouses'] = r['spouses']['value']
    if("conflictLabel" in r):
        roi['conflictLabel'] = r['conflictLabel']['value']
    if("startTime" in r):
        roi['startTime'] = r['startTime']['value']
    if("endTime" in r):
        roi['endTime'] = r['endTime']['value']
    rois.append(roi)

# %%
df = pd.DataFrame(rois)
df.count()
# Out:
# nom                   170
# dateOfBirth           167
# placeOfBirthLabel     149
# dateOfDeath           166
# placeOfDeathLabel     149
# placeOfBurialLabel    110
# fatherLabel           154
# motherLabel           136
# spouses               170
# startTime              80
# endTime                80
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.count()
# Out:
# nom                   170
# dateOfBirth           167
# placeOfBirthLabel     149
# dateOfDeath           166
# placeOfDeathLabel     149
# placeOfBurialLabel    110
# fatherLabel           154
# motherLabel           136
# spouses               170
# startTime              80
# endTime                80
# dtype: int64

# %%
pd.options.display.max_rows = 999

# %%
df = df.drop_duplicates(subset=["nom"])

# %%
df.count()
# Out:
# nom                   120
# dateOfBirth           117
# placeOfBirthLabel     102
# dateOfDeath           116
# placeOfDeathLabel     102
# placeOfBurialLabel     67
# fatherLabel           106
# motherLabel            89
# spouses               120
# startTime              50
# endTime                50
# dtype: int64

# %%
df.sort_values(by=['dateOfBirth'])

# %% [markdown]
# ### 4) Save in csv

# %%
df.to_csv("rois-france.csv")
