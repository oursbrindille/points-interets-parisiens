# %% [markdown]
# # Notebook requêtant wikidata en SPARQL

# %% [markdown]
# Imports

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import numpy as np
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# ### 1) Récupération de tous les rois de France

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT ?item ?itemLabel (GROUP_CONCAT(DISTINCT ?spouseLabel;separator=", ") AS ?spouses) (GROUP_CONCAT(DISTINCT ?mannerOfDeathLabel;separator=", ") AS ?mannersOfDeath) 
# ?dateOfBirth ?placeOfBirthLabel ?dateOfDeath ?placeOfDeathLabel ?placeOfBurialLabel ?fatherLabel ?motherLabel ?conflictLabel ?startTime ?endTime

WHERE
{
{?item wdt:P31 wd:Q5 .} 
{?item wdt:P39 wd:Q18384454 .} UNION {?item wdt:P39 wd:Q22923081} UNION {?item wdt:P39 wd:Q3439798}
{?item wdt:P569 ?dateOfBirth} UNION {MINUS {?item wdt:P569 ?dateOfBirth}}
{?item wdt:P19 ?placeOfBirth} UNION {MINUS {?item wdt:P19 ?placeOfBirth}}
{?item wdt:P570 ?dateOfDeath} UNION {MINUS {?item wdt:P570 ?dateOfDeath}}
{?item wdt:P19 ?placeOfDeath} UNION {MINUS {?item wdt:P19 ?placeOfDeath}}
{?item wdt:P509 ?mannerOfDeath} UNION {MINUS {?item wdt:P509 ?mannerOfDeath}}
{?item wdt:P119 ?placeOfBurial} UNION {MINUS {?item wdt:P119 ?placeOfBurial}}
{?item wdt:P22 ?father} UNION {MINUS {?item wdt:P22 ?father}}
{?item wdt:P25 ?mother} UNION {MINUS {?item wdt:P25 ?mother}}
{?item wdt:P26 ?spouse} UNION {MINUS {?item wdt:P26 ?spouse}}
{?item wdt:P607 ?conflict} UNION {MINUS {?item wdt:P607 ?conflict}}
# ?item p:P39 ?positionHeld.
{?positionHeld pq:P580 ?startTime.} UNION {MINUS {?positionHeld pq:P580 ?startTime.}}
{?positionHeld pq:P582 ?endTime.} UNION {MINUS {?positionHeld pq:P582 ?endTime.}}
  
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],fr" .
                         # ?item rdfs:label ?itemLabel .
                         # ?placeOfBirth rdfs:label ?placeOfBirthLabel .
                         # ?placeOfDeath rdfs:label ?placeOfDeathLabel .
                         # ?mannerOfDeath rdfs:label ?mannerOfDeathLabel .
                         # ?placeOfBurial rdfs:label ?placeOfBurialLabel .
                         # ?father rdfs:label ?fatherLabel .
                         # ?mother rdfs:label ?motherLabel .
                         # ?spouse rdfs:label ?spouseLabel .}
}GROUP BY ?item ?itemLabel ?dateOfBirth ?placeOfBirthLabel ?dateOfDeath ?placeOfDeathLabel ?placeOfBurialLabel ?fatherLabel ?motherLabel ?conflictLabel ?startTime ?endTime

""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results
# Out:
# {'head': {'vars': ['item',
#    'itemLabel',
#    'spouses',
#    'mannersOfDeath',
#    'dateOfBirth',
#    'placeOfBirthLabel',
#    'dateOfDeath',
#    'placeOfDeathLabel',
#    'placeOfBurialLabel',
#    'fatherLabel',
#    'motherLabel',
#    'conflictLabel',
#    'startTime',
#    'endTime']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q134259'},
#     'itemLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Louis VII de France'},
#     'dateOfBirth': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '
},
#     'fatherLabel': {'xml:lang': 'fr',
#      'type': 'literal',
#      'value': 'Caribert II'},
#     'spouses': {'type': 'literal', 'value': ''},
#     'mannersOfDeath': {'type': 'literal', 'value': ''}}]}}

# %%
rois = []
for r in results['results']['bindings']:
    roi = {}
    if("itemLabel" in r):
        roi['nom'] = r['itemLabel']['value']
    if("dateOfBirth" in r):
        roi['dateOfBirth'] = r['dateOfBirth']['value']
    if("placeOfBirthLabel" in r):
        roi['placeOfBirthLabel'] = r['placeOfBirthLabel']['value']
    if("dateOfDeath" in r):
        roi['dateOfDeath'] = r['dateOfDeath']['value']
    if("placeOfDeathLabel" in r):
        roi['placeOfDeathLabel'] = r['placeOfDeathLabel']['value']
    if("mannerOfDeathLabel" in r):
        roi['mannerOfDeathLabel'] = r['mannerOfDeathLabel']['value']
    if("placeOfBurialLabel" in r):
        roi['placeOfBurialLabel'] = r['placeOfBurialLabel']['value']
    if("fatherLabel" in r):
        roi['fatherLabel'] = r['fatherLabel']['value']
    if("motherLabel" in r):
        roi['motherLabel'] = r['motherLabel']['value']
    if("spouses" in r):
        roi['spouses'] = r['spouses']['value']
    if("conflictLabel" in r):
        roi['conflictLabel'] = r['conflictLabel']['value']
    if("startTime" in r):
        roi['startTime'] = r['startTime']['value']
    if("endTime" in r):
        roi['endTime'] = r['endTime']['value']
    rois.append(roi)

# %%
df = pd.DataFrame(rois)
df.count()
# Out:
# nom                   170
# dateOfBirth           167
# placeOfBirthLabel     149
# dateOfDeath           166
# placeOfDeathLabel     149
# placeOfBurialLabel    110
# fatherLabel           154
# motherLabel           136
# spouses               170
# startTime              80
# endTime                80
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.count()
# Out:
# nom                   170
# dateOfBirth           167
# placeOfBirthLabel     149
# dateOfDeath           166
# placeOfDeathLabel     149
# placeOfBurialLabel    110
# fatherLabel           154
# motherLabel           136
# spouses               170
# startTime              80
# endTime                80
# dtype: int64

# %%
pd.options.display.max_rows = 999

# %%
df = df.drop_duplicates(subset=["nom"])

# %%
df.count()
# Out:
# nom                   120
# dateOfBirth           117
# placeOfBirthLabel     102
# dateOfDeath           116
# placeOfDeathLabel     102
# placeOfBurialLabel     67
# fatherLabel           106
# motherLabel            89
# spouses               120
# startTime              50
# endTime                50
# dtype: int64

# %%
df.sort_values(by=['startTime'])
# Out:
#                          nom           dateOfBirth  \
# 34                 Mallobaud  0400-01-01T00:00:00Z
# 33                  Marcomir  0400-01-01T00:00:00Z
# 29                Clovis Ier  0466-01-01T00:00:00Z
# 50              Childéric II  0655-01-01T00:00:00Z
# 57               Thierry III  0657-01-01T00:00:00Z
# 52               Dagobert II  0652-01-01T00:00:00Z
# 32                 Clovis IV  0677-01-01T00:00:00Z
# 2              Childebert IV  0678-01-01T00:00:00Z
# 20              Dagobert III  0698-01-01T00:00:00Z
# 53               Clotaire IV  0685-01-01T00:00:00Z
# 7               Chilpéric II  0673-01-01T00:00:00Z
# 4                 Thierry IV  0712-01-01T00:00:00Z
# 25             Pépin le Bref  0714-01-01T00:00:00Z
# 31             Childéric III  0714-01-01T00:00:00Z
# 23              Carloman Ier  0751-01-01T00:00:00Z
# 35               Charlemagne  0748-04-06T00:00:00Z
# 73            Louis le Pieux  0778-04-20T00:00:00Z
# 107                       t1652299170  0567-01-01T00:00:00Z
# 108                       t1780198527  0811-12-08T00:00:00Z
# 109                       t1179998082  0863-01-29T00:00:00Z
# 110                       t1554304559  0676-01-01T00:00:00Z
# 111                               NaN  1026-01-01T00:00:00Z
# 113                               NaN  0508-01-01T00:00:00Z
# 114                               NaN  0400-01-01T00:00:00Z
# 115                               NaN                   NaN
# 116                               NaN                   NaN
# 117                       t1754001998  0570-01-01T00:00:00Z
# 118                       t1670898845  0639-01-22T00:00:00Z
# 119                       t1762582700  0899-12-12T00:00:00Z
# 120                        Montdidier  0597-12-10T00:00:00Z
# 121                       t1774066076  0810-07-12T00:00:00Z
# 122                       t1689588280  0632-04-08T00:00:00Z
# 123                       t1611686113  0656-02-04T00:00:00Z
# 124                       t1777773193           t1777773199
# 125                         t15270228             t15270229
# 126                              Lyon  0545-06-03T00:00:00Z
# 127                               NaN  0811-01-01T00:00:00Z
# 128                       t1777669356  0673-01-01T00:00:00Z
# 129                       t1589412189  0613-10-13T00:00:00Z
# 130                               NaN  0509-01-01T00:00:00Z
# 132                               NaN                   NaN
# 133                               NaN  0306-01-01T00:00:00Z
# 134                               NaN                   NaN
# 135                         Altötting  0911-10-04T00:00:00Z
# 136                       t1462480740  0882-01-24T00:00:00Z
# 137                             Reims  0558-12-13T00:00:00Z
# 139                       t1560140345  0448-01-01T00:00:00Z
# 140                       t1780224668  0869-08-12T00:00:00Z
# 141                        t352240511  0612-01-01T00:00:00Z
# 142                       t1725712643  0585-03-01T00:00:00Z
# 143                               NaN  0679-01-01T00:00:00Z
# 145                       t1680024959           t1680024960
# 151                       t1657730630  0843-04-23T00:00:00Z
# 152                       t1774564747  0548-01-01T00:00:00Z
# 153                       t1777639808  0662-01-01T00:00:00Z
# 154                       t1777669362  0575-01-01T00:00:00Z
# 155             Francfort-sur-le-Main  0866-10-03T00:00:00Z
# 156                               NaN  0306-01-01T00:00:00Z
# 158                       t1545842460  0887-01-15T00:00:00Z
# 159                              Saxe  0936-07-07T00:00:00Z
# 160                            Tolède  0568-01-01T00:00:00Z
# 161                       t1774520309  0680-01-30T00:00:00Z
# 162                          Soissons  0593-03-30T00:00:00Z
# 164                       t1780316954  0818-04-21T00:00:00Z
# 168                       t1394245358  0632-01-01T00:00:00Z
#
#                     placeOfDeathLabel  \
# 34                                NaN
# 33                                NaN
# 29                            Tournai
# 50                        t1589541665
# 57                        t1551909395
# 52                        t1554304759
# 32                        t1716563649
# 2                         t1775585407
# 20                        t1554304902
# 53                        t1421563132
# 7                         t1774396202
# 4                          t349901652
# 25                              Liège
# 31                        t1422240388
# 23                           Soissons
# 35                 Royaume des Francs
# 73              Chasseneuil-du-Poitou
# 5                             Dourdan
# 18                            Orléans
# 14                              Reims
# 72              Champagne-et-Fontaine
# 6                               Paris
# 0                               Paris
# 75                              Paris
# 1                               Paris
# 76                             Poissy
# 74                             Poissy
# 21                      Fontainebleau
# 65                          Vincennes
# 17                              Creil
# 16                      Fontainebleau
# 70                            Le Mans
# 15                          Vincennes
# 13                              Paris
# 3                               Paris
# 60                            Bourges
# 12                            Amboise
# 79                              Blois
# 69                             Cognac
# 11              Saint-Germain-en-Laye
# 30                      Fontainebleau
# 19              Saint-Germain-en-Laye
# 55                     château de Pau
# 77           château de Fontainebleau
# 54                      Fontainebleau
# 63   château de Saint-Germain-en-Laye
# 66                         Versailles
# 61              château de Versailles
# 67                         Versailles
# 64                         Versailles
# 80                           Soissons
# 84                        t1398551735
# 85                             Erfurt
# 86                        t1609450070
# 87                        t1777669361
# 89                        t1780316949
# 90                                NaN
# 91                                NaN
# 92                        t1675385804
# 93                        t1774475162
# 94                        t1614691788
# 95                        t1773984423
# 96                        t1581916553
# 97                        t1375013901
# 98                        t1774594024
# 99                              Arles
# 100                               NaN
# 101                               NaN
# 103                       t1776591244
# 104                            Mérida
# 105                            Souabe
# 106                       t1623154973
# 107                       t1652299170
# 108                       t1780198527
# 109                       t1179998082
# 110                       t1554304559
# 111                               NaN
# 113                               NaN
# 114                               NaN
# 115                               NaN
# 116                               NaN
# 117                       t1754001998
# 118                       t1670898845
# 119                       t1762582700
# 120                        Montdidier
# 121                       t1774066076
# 122                       t1689588280
# 123                       t1611686113
# 124                       t1777773193
# 125                         t15270228
# 126                              Lyon
# 127                               NaN
# 128                       t1777669356
# 129                       t1589412189
# 130                               NaN
# 132                               NaN
# 133                               NaN
# 134                               NaN
# 135                         Altötting
# 136                       t1462480740
# 137                             Reims
# 139                       t1560140345
# 140                       t1780224668
# 141                        t352240511
# 142                       t1725712643
# 143                               NaN
# 145                       t1680024959
# 151                       t1657730630
# 152                       t1774564747
# 153                       t1777639808
# 154                       t1777669362
# 155             Francfort-sur-le-Main
# 156                               NaN
# 158                       t1545842460
# 159                              Saxe
# 160                            Tolède
# 161                       t1774520309
# 162                          Soissons
# 164                   Hauts-de-France
# 168                       t1394245358
#
#                            placeOfBurialLabel             fatherLabel  \
# 34                                        NaN                     NaN
# 33                                        NaN                     NaN
# 29           abbaye Sainte-Geneviève de Paris           Childéric Ier
# 50           abbaye de Saint-Germain-des-Prés               Clovis II
# 57                                      Arras               Clovis II
# 52                                        NaN            Sigebert III
# 32                                        NaN             Thierry III
# 2                                         NaN             Thierry III
# 20                                        NaN           Childebert IV
# 53                                        NaN           Childebert IV
# 7                                       Noyon            Childéric II
# 4                       basilique Saint-Denis            Dagobert III
# 25                      basilique Saint-Denis          Charles Martel
# 31                                        NaN            Chilpéric II
# 23                      basilique Saint-Denis           Pépin le Bref
# 35               cathédrale d'Aix-la-Chapelle           Pépin le Bref
# 73                    abbaye de Saint-Arnould             Charlemagne
# 5                       basilique Saint-Denis         Hugues le Grand
# 18                      basilique Saint-Denis            Hugues Capet
# 14                      basilique Saint-Denis     Robert II de France
# 72           abbaye de Saint-Benoît-sur-Loire     Henri Ier de France
# 6                       basilique Saint-Denis  Philippe Ier de France
# 0                       basilique Saint-Denis      Louis VI de France
# 75                      basilique Saint-Denis     Louis VII de France
# 1                       basilique Saint-Denis     Philippe II Auguste
# 76                      basilique Saint-Denis    Louis VIII de France
# 74                      basilique Saint-Denis             Saint Louis
# 21                      basilique Saint-Denis  Philippe III de France
# 65                      basilique Saint-Denis   Philippe IV de France
# 17                      basilique Saint-Denis   Philippe IV de France
# 16                      basilique Saint-Denis       Charles de Valois
# 70                      basilique Saint-Denis   Philippe VI de France
# 15                      basilique Saint-Denis       Jean II de France
# 13                      basilique Saint-Denis     Charles V de France
# 3                       basilique Saint-Denis              Charles VI
# 60              basilique Notre-Dame de Cléry   Charles VII de France
# 12                      basilique Saint-Denis                Louis XI
# 79                      basilique Saint-Denis       Charles d'Orléans
# 69                      basilique Saint-Denis       Charles d'Orléans
# 11                      basilique Saint-Denis            François Ier
# 30                      basilique Saint-Denis                Henri II
# 19                      basilique Saint-Denis                Henri II
# 55                      basilique Saint-Denis      Antoine de Bourbon
# 77                      basilique Saint-Denis                Henri II
# 54                      basilique Saint-Denis                Henri IV
# 63                      basilique Saint-Denis              Louis XIII
# 66                      basilique Saint-Denis         Louis de France
# 61                      basilique Saint-Denis         Louis de France
# 67                      basilique Saint-Denis         Louis de France
# 64   église de l'Annonciation de Kostanjevica         Louis de France
# 80                                        NaN              Clovis Ier
# 84                                        NaN              Clovis Ier
# 85        église Sainte-Radegonde de Poitiers               Berthaire
# 86                                        NaN          Théodebert Ier
# 87                      basilique Saint-Denis            Dagobert Ier
# 89                         Nouvelle-Aquitaine          Louis le Pieux
# 90                                      Milan          Hugues d'Arles
# 91                                        NaN                Hugobert
# 92                                        NaN      Clodion le Chevelu
# 93                                        NaN              Clovis Ier
# 94           abbaye de Saint-Germain-des-Prés           Chilpéric Ier
# 95                   basilique Saint-Ambroise            Lothaire Ier
# 96                         abbaye de Süsteren     Arnulf de Carinthie
# 97                                        NaN                     NaN
# 98                                        NaN            Sigebert Ier
# 99                                        NaN        Théobald d'Arles
# 100                                       NaN                     NaN
# 101                                       NaN                     NaN
# 103                                   Tournai                 Mérovée
# 104                                       NaN         Athanagilde Ier
# 105                   abbaye de Saint-Arnould  Gérold Ier de Vintzgau
# 106          abbaye de Saint-Germain-des-Prés            Clotaire Ier
# 107                                       NaN            Clotaire Ier
# 108                                       NaN             Charlemagne
# 109                                       NaN            Lothaire Ier
# 110                                       NaN            Clotaire III
# 111                                 Compiègne     Robert II de France
# 113                                       NaN     Sigebert le Boiteux
# 114                                       NaN                     NaN
# 115                                       NaN                     NaN
# 116                                       NaN                     NaN
# 117                                       NaN                  Waccho
# 118                     basilique Saint-Denis             Clotaire II
# 119                                 Q19309358     Carloman de Bavière
# 120                     basilique Saint-Denis                     NaN
# 121                                     Milan             Charlemagne
# 122                                       NaN             Clotaire II
# 123                                       NaN            Dagobert Ier
# 124                                       NaN   Pépin Ier d'Aquitaine
# 125                                       NaN           Childéric III
# 126            cathédrale Notre-Dame de Paris            Chilpéric II
# 127                                       NaN             Charlemagne
# 128                     basilique Saint-Denis               Clovis II
# 129                                       NaN              Thierry II
# 130                                       NaN                     NaN
# 132                                       NaN                Richomer
# 133                                       NaN                     NaN
# 134                                       NaN                     NaN
# 135                                 Q19309358     Arnulf de Carinthie
# 136                          abbaye de Lorsch  Louis II le Germanique
# 137                     basilique Saint-Denis              Clovis Ier
# 139                                       NaN               Théodomir
# 140                                  Q1670729            Lothaire Ier
# 141                                       NaN           Childebert II
# 142                                       NaN            Clotaire Ier
# 143                                       NaN             Dagobert II
# 145                                       NaN               Sigismond
# 151                       Centre-Val de Loire                Welf Ier
# 152                                       NaN             Thierry Ier
# 153                                       NaN            Grimoald Ier
# 154                                       NaN            Clotaire Ier
# 155                       Centre-Val de Loire    Charles II le Chauve
# 156                                       NaN                     NaN
# 158                                       NaN                   Bivin
# 159                    abbaye de Quedlinbourg       Otton Ier de Saxe
# 160                                       NaN         Athanagilde Ier
# 161                                       NaN                     NaN
# 162                                       NaN            Clotaire Ier
# 164                                 Lombardie          Pépin d'Italie
# 168                                       NaN             Caribert II
#
#                   motherLabel  \
# 34                        NaN
# 33                        NaN
# 29         Basine de Thuringe
# 50                   Bathilde
# 57                   Bathilde
# 52               Chimnechilde
# 32         Clotilde dite Doda
# 2          Clotilde dite Doda
# 20                        NaN
# 53                        NaN
# 7                  Bilichilde
# 4                         NaN
# 25                    Rotrude
# 31                        NaN
# 23           Bertrade de Laon
# 35           Bertrade de Laon
# 73                 Hildegarde
# 5             Hedwige de Saxe
# 18       Adélaïde d'Aquitaine
# 14          Constance d'Arles
# 72               Anne de Kiev
# 6          Berthe de Hollande
# 0          Adélaïde de Savoie
# 75         Adèle de Champagne
# 1         Isabelle de Hainaut
# 76        Blanche de Castille
# 74     Marguerite de Provence
# 21          Isabelle d'Aragon
# 65      Jeanne Ire de Navarre
# 17      Jeanne Ire de Navarre
# 16         Marguerite d'Anjou
# 70        Jeanne de Bourgogne
# 15        Bonne de Luxembourg
# 13          Jeanne de Bourbon
# 3          Isabeau de Bavière
# 60              Marie d'Anjou
# 12        Charlotte de Savoie
# 79            Marie de Clèves
# 69           Louise de Savoie
# 11           Claude de France
# 30       Catherine de Médicis
# 19       Catherine de Médicis
# 55            Jeanne d'Albret
# 77       Catherine de Médicis
# 54           Marie de Médicis
# 63            Anne d'Autriche
# 66   Marie-Adélaïde de Savoie
# 61      Marie-Josèphe de Saxe
# 67      Marie-Josèphe de Saxe
# 64      Marie-Josèphe de Saxe
# 80                   Clotilde
# 84          princesse franque
# 85                        NaN
# 86                   Deoteria
# 87                   Nantilde
# 89      Ermengarde de Hesbaye
# 90                      Hilda
# 91             Irmina d'Oeren
# 92                        NaN
# 93                   Clotilde
# 94                 Frédégonde
# 95        Ermengarde de Tours
# 96                    Winburg
# 97                        NaN
# 98                  Brunehaut
# 99                     Berthe
# 100                       NaN
# 101                       NaN
# 103                       NaN
# 104                 Goswinthe
# 105           Emma d'Alémanie
# 106                  Arégonde
# 107                   Ingonde
# 108                Hildegarde
# 109       Ermengarde de Tours
# 110                       NaN
# 111         Constance d'Arles
# 113                       NaN
# 114                       NaN
# 115                       NaN
# 116                       NaN
# 117                 Q19891002
# 118                  Bertrude
# 119                Liutswinde
# 120                       NaN
# 121                Hildegarde
# 122                  Sichilde
# 123                Ragnétrude
# 124    Ingeltrude ou Ringarde
# 125                       NaN
# 126                       NaN
# 127                Himiltrude
# 128                  Bathilde
# 129                       NaN
# 130                       NaN
# 132                       NaN
# 133                       NaN
# 134                       NaN
# 135                       Oda
# 136           Emma de Bavière
# 137                  Clotilde
# 139                       NaN
# 140       Ermengarde de Tours
# 141                  Faileube
# 142                  Waldrade
# 143                       NaN
# 145                 Q12289430
# 151                   Heilwig
# 152                        Ne
# 153                       NaN
# 154                   Ingonde
# 155      Ermentrude d'Orléans
# 156                       NaN
# 158                 Q61717067
# 159                   Hedwige
# 160                 Goswinthe
# 161                       NaN
# 162                   Ingonde
# 164                  Chrotais
# 168                       NaN
#
#                                                spouses             startTime  \
# 34                                                      0378-01-01T00:00:00Z
# 33                                                      0380-01-01T00:00:00Z
# 29                         princesse franque, Clotilde  0481-01-01T00:00:00Z
# 50                                          Bilichilde  0673-01-01T00:00:00Z
# 57                                  Clotilde dite Doda  0675-01-01T00:00:00Z
# 52                                                      0676-01-01T00:00:00Z
# 32                                                      0691-01-01T00:00:00Z
# 2                                                       0695-01-01T00:00:00Z
# 20                                                      0711-01-01T00:00:00Z
# 53                                                      0717-01-01T00:00:00Z
# 7                                                       0719-01-01T00:00:00Z
# 4                                                       0721-01-01T00:00:00Z
# 25                                    Bertrade de Laon  0741-01-01T00:00:00Z
# 31                                                      0743-01-01T00:00:00Z
# 23                                            Gerberge  0768-10-13T00:00:00Z
# 35   Himiltrude, Désirée de Lombardie, Luitgarde, F...  0800-12-29T00:00:00Z
# 73            Ermengarde de Hesbaye, Judith de Bavière  0814-02-01T00:00:00Z
# 5                                 Adélaïde d'Aquitaine  0987-06-08T00:00:00Z
# 18   Rozala d'Italie, Berthe de Bourgogne, Constanc...  0996-10-29T00:00:00Z
# 14   Mathilde de Franconie, Anne de Kiev, Mathilde ...  1031-07-16T00:00:00Z
# 72            Bertrade de Montfort, Berthe de Hollande  1060-08-10T00:00:00Z
# 6            Lucienne de Rochefort, Adélaïde de Savoie  1108-08-06T00:00:00Z
# 0    Constance de Castille, Adèle de Champagne, Ali...  1137-08-08T00:00:00Z
# 75   Agnès de Méranie, Isabelle de Hainaut, Ingebur...  1180-09-25T00:00:00Z
# 1                                  Blanche de Castille  1223-07-21T00:00:00Z
# 76                              Marguerite de Provence  1226-11-15T00:00:00Z
# 74                 Isabelle d'Aragon, Marie de Brabant  1270-09-01T00:00:00Z
# 21                               Jeanne Ire de Navarre  1285-10-12T00:00:00Z
# 65                                 Jeanne de Bourgogne  1316-11-27T00:00:00Z
# 17   Blanche de Bourgogne, Marie de Luxembourg, Jea...  1322-01-11T00:00:00Z
# 16             Blanche de Navarre, Jeanne de Bourgogne  1328-04-09T00:00:00Z
# 70          Jeanne Ire d'Auvergne, Bonne de Luxembourg  1350-08-30T00:00:00Z
# 15                                   Jeanne de Bourbon  1364-04-16T00:00:00Z
# 13                                  Isabeau de Bavière  1380-09-24T00:00:00Z
# 3                                        Marie d'Anjou  1422-11-08T00:00:00Z
# 60            Marguerite d'Écosse, Charlotte de Savoie  1461-08-09T00:00:00Z
# 12                                    Anne de Bretagne  1483-09-17T00:00:00Z
# 79   Marie d'Angleterre, Jeanne de France, Anne de ...  1498-04-25T00:00:00Z
# 69             Éléonore de Habsbourg, Claude de France  1515-01-11T00:00:00Z
# 11                                Catherine de Médicis  1547-04-10T00:00:00Z
# 30                                        Marie Stuart  1559-07-30T00:00:00Z
# 19                                Élisabeth d'Autriche  1560-12-25T00:00:00Z
# 55              Marguerite de France, Marie de Médicis  1572-06-19T00:00:00Z
# 77                                  Louise de Lorraine  1573-05-11T00:00:00Z
# 54                                     Anne d'Autriche  1610-05-14T00:00:00Z
# 63       Madame de Maintenon, Marie-Thérèse d'Autriche  1643-05-14T00:00:00Z
# 66                                   Marie Leszczyńska  1715-09-01T00:00:00Z
# 61                                    Marie-Antoinette  1791-09-04T00:00:00Z
# 67                           Marie-Joséphine de Savoie  1815-07-08T00:00:00Z
# 64                             Marie-Thérèse de Savoie  1824-09-16T00:00:00Z
# 80   Arégonde, Waldrade, Radegonde, Chunsène, Gondi...                   NaN
# 84                                      Ne, Suavegothe                   NaN
# 85                                        Clotaire Ier                   NaN
# 86                                            Waldrade                   NaN
# 87                                            Bathilde                   NaN
# 89                              Ingeltrude ou Ringarde                   NaN
# 90                               Adélaïde de Bourgogne                   NaN
# 91                                    Pépin de Herstal                   NaN
# 92                                                                       NaN
# 93                                           Gondioque                   NaN
# 94                      Bertrude, Sichilde, Haldetrude                   NaN
# 95                                          Engelberge                   NaN
# 96                                         Oda de Saxe                   NaN
# 97                                       Chilpéric Ier                   NaN
# 98                                            Faileube                   NaN
# 99   Willa de Provence, Hilda, Berthe de Souabe, Ma...                   NaN
# 100                                                                      NaN
# 101                                                                      NaN
# 103                                 Basine de Thuringe                   NaN
# 104                              Mérovée, Sigebert Ier                   NaN
# 105                                        Charlemagne                   NaN
# 106                   Audovère, Galswinthe, Frédégonde                   NaN
# 107        Théodechilde, Méroflède, Marcova, Ingeberge                   NaN
# 108                                                                      NaN
# 109                                                                      NaN
# 110                                                                      NaN
# 111                                                                      NaN
# 113                                                                      NaN
# 114                                                                      NaN
# 115                                                                      NaN
# 116                                                                      NaN
# 117  Garibald Ier de Bavière, Théodebald, Clotaire Ier                   NaN
# 118  Berchilde, Wulfégonde, Ragnétrude, Gomatrude, ...                   NaN
# 119                                                Oda                   NaN
# 120                                      Chilpéric Ier                   NaN
# 121                                                                      NaN
# 122                                                                      NaN
# 123                                       Chimnechilde                   NaN
# 124                                                                      NaN
# 125                                                                      NaN
# 126                                         Clovis Ier                   NaN
# 127                                                                      NaN
# 128                                                                      NaN
# 129                                                                      NaN
# 130                                                                      NaN
# 132                                                                      NaN
# 133                                                                      NaN
# 134                                                                      NaN
# 135                                        t1774443022                   NaN
# 136                                  Liutgarde de Saxe                   NaN
# 137                                         Ultrogothe                   NaN
# 139                                                                      NaN
# 140                                          Teutberge                   NaN
# 141                            Théodechilde, Blichilde                   NaN
# 142                                                                      NaN
# 143                                                                      NaN
# 145                                        Thierry Ier                   NaN
# 151                                     Louis le Pieux                   NaN
# 152                                Deoteria, Wisigarde                   NaN
# 153                                                                      NaN
# 154                                          Brunehaut                   NaN
# 155                                                                      NaN
# 156                                                                      NaN
# 158                                         Ermengarde                   NaN
# 159                   Q3555663, Mathilde de Ringelheim                   NaN
# 160                                      Chilpéric Ier                   NaN
# 161                                          Clovis II                   NaN
# 162                            Marcatrude, Austregilde                   NaN
# 164                                          Cunégonde                   NaN
# 168                                                                      NaN
#
#                   endTime
# 34   0378-01-01T00:00:00Z
# 33   0400-01-01T00:00:00Z
# 29   0511-11-29T00:00:00Z
# 50   0675-01-01T00:00:00Z
# 57   0679-01-01T00:00:00Z
# 52   0679-12-26T00:00:00Z
# 32   0695-01-01T00:00:00Z
# 2    0711-01-01T00:00:00Z
# 20   0715-01-01T00:00:00Z
# 53   0719-01-01T00:00:00Z
# 7    0721-01-01T00:00:00Z
# 4    0737-01-01T00:00:00Z
# 25   0751-01-01T00:00:00Z
# 31   0751-01-01T00:00:00Z
# 23   0771-12-08T00:00:00Z
# 35   0814-02-01T00:00:00Z
# 73   0840-06-24T00:00:00Z
# 5    0996-10-29T00:00:00Z
# 18   1031-07-26T00:00:00Z
# 14   1060-08-10T00:00:00Z
# 72   1108-08-05T00:00:00Z
# 6    1137-08-08T00:00:00Z
# 0    1180-09-25T00:00:00Z
# 75   1223-07-21T00:00:00Z
# 1    1226-11-15T00:00:00Z
# 76   1270-09-01T00:00:00Z
# 74   1285-10-12T00:00:00Z
# 21   1314-12-07T00:00:00Z
# 65   1322-01-11T00:00:00Z
# 17   1328-02-09T00:00:00Z
# 16   1350-08-30T00:00:00Z
# 70   1364-04-16T00:00:00Z
# 15   1380-09-24T00:00:00Z
# 13   1422-10-30T00:00:00Z
# 3    1461-08-09T00:00:00Z
# 60   1483-09-17T00:00:00Z
# 12   1498-04-25T00:00:00Z
# 79   1515-01-11T00:00:00Z
# 69   1547-04-10T00:00:00Z
# 11   1559-07-20T00:00:00Z
# 30   1560-12-25T00:00:00Z
# 19   1574-06-19T00:00:00Z
# 55   1610-05-14T00:00:00Z
# 77   1574-06-18T00:00:00Z
# 54   1643-05-14T00:00:00Z
# 63   1715-09-01T00:00:00Z
# 66   1774-05-10T00:00:00Z
# 61   1792-08-10T00:00:00Z
# 67   1824-09-16T00:00:00Z
# 64   1830-08-02T00:00:00Z
# 80                    NaN
# 84                    NaN
# 85                    NaN
# 86                    NaN
# 87                    NaN
# 89                    NaN
# 90                    NaN
# 91                    NaN
# 92                    NaN
# 93                    NaN
# 94                    NaN
# 95                    NaN
# 96                    NaN
# 97                    NaN
# 98                    NaN
# 99                    NaN
# 100                   NaN
# 101                   NaN
# 103                   NaN
# 104                   NaN
# 105                   NaN
# 106                   NaN
# 107                   NaN
# 108                   NaN
# 109                   NaN
# 110                   NaN
# 111                   NaN
# 113                   NaN
# 114                   NaN
# 115                   NaN
# 116                   NaN
# 117                   NaN
# 118                   NaN
# 119                   NaN
# 120                   NaN
# 121                   NaN
# 122                   NaN
# 123                   NaN
# 124                   NaN
# 125                   NaN
# 126                   NaN
# 127                   NaN
# 128                   NaN
# 129                   NaN
# 130                   NaN
# 132                   NaN
# 133                   NaN
# 134                   NaN
# 135                   NaN
# 136                   NaN
# 137                   NaN
# 139                   NaN
# 140                   NaN
# 141                   NaN
# 142                   NaN
# 143                   NaN
# 145                   NaN
# 151                   NaN
# 152                   NaN
# 153                   NaN
# 154                   NaN
# 155                   NaN
# 156                   NaN
# 158                   NaN
# 159                   NaN
# 160                   NaN
# 161                   NaN
# 162                   NaN
# 164                   NaN
# 168                   NaN

# %%
df2 = df[df['startTime'].notna() & df['endTime'].notna()]

# %%
df2.shape
# Out:
# (50, 11)

# %%
from datetime import datetime

# %%
df2['startYear'] = df2['startTime'].map(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S%z").year)
df2['endYear'] = df2['endTime'].map(lambda x: datetime.strptime(x, "%Y-%m-%dT%H:%M:%S%z").year)
# Out:
# /home/geof/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/geof/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#                        nom           dateOfBirth  \
# 0      Louis VII de France  1120-01-01T00:00:00Z
# 1     Louis VIII de France  1187-09-12T00:00:00Z
# 2            Childebert IV  0678-01-01T00:00:00Z
# 3    Charles VII de France  1403-03-03T00:00:00Z
# 4               Thierry IV  0712-01-01T00:00:00Z
# 5             Hugues Capet  0940-01-01T00:00:00Z
# 6       Louis VI de France  1081-12-07T00:00:00Z
# 7             Chilpéric II  0673-01-01T00:00:00Z
# 11                Henri II  1519-04-10T00:00:00Z
# 12            Charles VIII  1470-07-09T00:00:00Z
# 13              Charles VI  1368-12-11T00:00:00Z
# 14     Henri Ier de France  1008-05-04T00:00:00Z
# 15     Charles V de France  1338-01-29T00:00:00Z
# 16   Philippe VI de France  1293-11-24T00:00:00Z
# 17    Charles IV de France  1294-06-25T00:00:00Z
# 18     Robert II de France  0972-04-01T00:00:00Z
# 19              Charles IX  1550-07-07T00:00:00Z
# 20            Dagobert III  0698-01-01T00:00:00Z
# 21   Philippe IV de France  1268-01-01T00:00:00Z
# 23            Carloman Ier  0751-01-01T00:00:00Z
# 25           Pépin le Bref  0714-01-01T00:00:00Z
# 29              Clovis Ier  0466-01-01T00:00:00Z
# 30             François II  1544-01-29T00:00:00Z
# 31           Childéric III  0714-01-01T00:00:00Z
# 32               Clovis IV  0677-01-01T00:00:00Z
# 33                Marcomir  0400-01-01T00:00:00Z
# 34               Mallobaud  0400-01-01T00:00:00Z
# 35             Charlemagne  0748-04-06T00:00:00Z
# 50            Childéric II  0655-01-01T00:00:00Z
# 52             Dagobert II  0652-01-01T00:00:00Z
# 53             Clotaire IV  0685-01-01T00:00:00Z
# 54              Louis XIII  1601-09-27T00:00:00Z
# 55                Henri IV  1553-12-23T00:00:00Z
# 57             Thierry III  0657-01-01T00:00:00Z
# 70                           Le Mans  1364-04-16T00:00:00Z
# 72             Champagne-et-Fontaine  1108-08-05T00:00:00Z
# 73             Chasseneuil-du-Poitou  0840-06-24T00:00:00Z
# 74                            Poissy  1285-10-12T00:00:00Z
# 75                             Paris  1223-07-21T00:00:00Z
# 76                            Poissy  1270-09-01T00:00:00Z
# 77          château de Fontainebleau  1589-08-02T00:00:00Z
# 79                             Blois  1515-01-11T00:00:00Z
#
#                    placeOfDeathLabel  \
# 0                              Paris
# 1                              Paris
# 2                        t1775585407
# 3                              Paris
# 4                         t349901652
# 5                            Dourdan
# 6                              Paris
# 7                        t1774396202
# 11             Saint-Germain-en-Laye
# 12                           Amboise
# 13                             Paris
# 14                             Reims
# 15                         Vincennes
# 16                     Fontainebleau
# 17                             Creil
# 18                           Orléans
# 19             Saint-Germain-en-Laye
# 20                       t1554304902
# 21                     Fontainebleau
# 23                          Soissons
# 25                             Liège
# 29                           Tournai
# 30                     Fontainebleau
# 31                       t1422240388
# 32                       t1716563649
# 33                               NaN
# 34                               NaN
# 35                Royaume des Francs
# 50                       t1589541665
# 52                       t1554304759
# 53                       t1421563132
# 54                     Fontainebleau
# 55                    château de Pau
# 57                       t1551909395
# 60                           Bourges
# 61             château de Versailles
# 63  château de Saint-Germain-en-Laye
# 64                        Versailles
# 65                         Vincennes
# 66                        Versailles
# 67                        Versailles
# 69                            Cognac
# 70                           Le Mans
# 72             Champagne-et-Fontaine
# 73             Chasseneuil-du-Poitou
# 74                            Poissy
# 75                             Paris
# 76                            Poissy
# 77          château de Fontainebleau
# 79                             Blois
#
#                           placeOfBurialLabel             fatherLabel  \
# 0                      basilique Saint-Denis      Louis VI de France
# 1                      basilique Saint-Denis     Philippe II Auguste
# 2                                        NaN             Thierry III
# 3                      basilique Saint-Denis              Charles VI
# 4                      basilique Saint-Denis            Dagobert III
# 5                      basilique Saint-Denis         Hugues le Grand
# 6                      basilique Saint-Denis  Philippe Ier de France
# 7                                      Noyon            Childéric II
# 11                     basilique Saint-Denis            François Ier
# 12                     basilique Saint-Denis                Louis XI
# 13                     basilique Saint-Denis     Charles V de France
# 14                     basilique Saint-Denis     Robert II de France
# 15                     basilique Saint-Denis       Jean II de France
# 16                     basilique Saint-Denis       Charles de Valois
# 17                     basilique Saint-Denis   Philippe IV de France
# 18                     basilique Saint-Denis            Hugues Capet
# 19                     basilique Saint-Denis                Henri II
# 20                                       NaN           Childebert IV
# 21                     basilique Saint-Denis  Philippe III de France
# 23                     basilique Saint-Denis           Pépin le Bref
# 25                     basilique Saint-Denis          Charles Martel
# 29          abbaye Sainte-Geneviève de Paris           Childéric Ier
# 30                     basilique Saint-Denis                Henri II
# 31                                       NaN            Chilpéric II
# 32                                       NaN             Thierry III
# 33                                       NaN                     NaN
# 34                                       NaN                     NaN
# 35              cathédrale d'Aix-la-Chapelle           Pépin le Bref
# 50          abbaye de Saint-Germain-des-Prés               Clovis II
# 52                                       NaN            Sigebert III
# 53                                       NaN           Childebert IV
# 54                     basilique Saint-Denis                Henri IV
# 55                     basilique Saint-Denis      Antoine de Bourbon
# 57                                     Arras               Clovis II
# 60             basilique Notre-Dame de Cléry   Charles VII de France
# 61                     basilique Saint-Denis         Louis de France
# 63                     basilique Saint-Denis              Louis XIII
# 64  église de l'Annonciation de Kostanjevica         Louis de France
# 65                     basilique Saint-Denis   Philippe IV de France
# 66                     basilique Saint-Denis         Louis de France
# 67                     basilique Saint-Denis         Louis de France
# 69                     basilique Saint-Denis       Charles d'Orléans
# 70                     basilique Saint-Denis   Philippe VI de France
# 72          abbaye de Saint-Benoît-sur-Loire     Henri Ier de France
# 73                   abbaye de Saint-Arnould             Charlemagne
# 74                     basilique Saint-Denis             Saint Louis
# 75                     basilique Saint-Denis     Louis VII de France
# 76                     basilique Saint-Denis    Louis VIII de France
# 77                     basilique Saint-Denis                Henri II
# 79                     basilique Saint-Denis       Charles d'Orléans
#
#                  motherLabel  \
# 0         Adélaïde de Savoie
# 1        Isabelle de Hainaut
# 2         Clotilde dite Doda
# 3         Isabeau de Bavière
# 4                        NaN
# 5            Hedwige de Saxe
# 6         Berthe de Hollande
# 7                 Bilichilde
# 11          Claude de France
# 12       Charlotte de Savoie
# 13         Jeanne de Bourbon
# 14         Constance d'Arles
# 15       Bonne de Luxembourg
# 16        Marguerite d'Anjou
# 17     Jeanne Ire de Navarre
# 18      Adélaïde d'Aquitaine
# 19      Catherine de Médicis
# 20                       NaN
# 21         Isabelle d'Aragon
# 23          Bertrade de Laon
# 25                   Rotrude
# 29        Basine de Thuringe
# 30      Catherine de Médicis
# 31                       NaN
# 32        Clotilde dite Doda
# 33                       NaN
# 34                       NaN
# 35          Bertrade de Laon
# 50                  Bathilde
# 52              Chimnechilde
# 53                       NaN
# 54          Marie de Médicis
# 55           Jeanne d'Albret
# 57                  Bathilde
# 60             Marie d'Anjou
# 61     Marie-Josèphe de Saxe
# 63           Anne d'Autriche
# 64     Marie-Josèphe de Saxe
# 65     Jeanne Ire de Navarre
# 66  Marie-Adélaïde de Savoie
# 67     Marie-Josèphe de Saxe
# 69          Louise de Savoie
# 70       Jeanne de Bourgogne
# 72              Anne de Kiev
# 73                Hildegarde
# 74    Marguerite de Provence
# 75        Adèle de Champagne
# 76       Blanche de Castille
# 77      Catherine de Médicis
# 79           Marie de Clèves
#
#                                               spouses             startTime  \
# 0   Constance de Castille, Adèle de Champagne, Ali...  1137-08-08T00:00:00Z
# 1                                 Blanche de Castille  1223-07-21T00:00:00Z
# 2                                                      0695-01-01T00:00:00Z
# 3                                       Marie d'Anjou  1422-11-08T00:00:00Z
# 4                                                      0721-01-01T00:00:00Z
# 5                                Adélaïde d'Aquitaine  0987-06-08T00:00:00Z
# 6           Lucienne de Rochefort, Adélaïde de Savoie  1108-08-06T00:00:00Z
# 7                                                      0719-01-01T00:00:00Z
# 11                               Catherine de Médicis  1547-04-10T00:00:00Z
# 12                                   Anne de Bretagne  1483-09-17T00:00:00Z
# 13                                 Isabeau de Bavière  1380-09-24T00:00:00Z
# 11  1559-07-20T00:00:00Z       1547     1559
# 12  1498-04-25T00:00:00Z       1483     1498
# 13  1422-10-30T00:00:00Z       1380     1422
# 14  1060-08-10T00:00:00Z       1031     1060
# 15  1380-09-24T00:00:00Z       1364     1380
# 16  1350-08-30T00:00:00Z       1328     1350
# 17  1328-02-09T00:00:00Z       1322     1328
# 18  1031-07-26T00:00:00Z        996     1031
# 19  1574-06-19T00:00:00Z       1560     1574
# 20  0715-01-01T00:00:00Z        711      715
# 21  1314-12-07T00:00:00Z       1285     1314
# 23  0771-12-08T00:00:00Z        768      771
# 25  0751-01-01T00:00:00Z        741      751
# 29  0511-11-29T00:00:00Z        481      511
# 30  1560-12-25T00:00:00Z       1559     1560
# 31  0751-01-01T00:00:00Z        743      751
# 32  0695-01-01T00:00:00Z        691      695
# 33  0400-01-01T00:00:00Z        380      400
# 34  0378-01-01T00:00:00Z        378      378
# 35  0814-02-01T00:00:00Z        800      814
# 50  0675-01-01T00:00:00Z        673      675
# 52  0679-12-26T00:00:00Z        676      679
# 53  0719-01-01T00:00:00Z        717      719
# 54  1643-05-14T00:00:00Z       1610     1643
# 55  1610-05-14T00:00:00Z       1572     1610
# 57  0679-01-01T00:00:00Z        675      679
# 60  1483-09-17T00:00:00Z       1461     1483
# 61  1792-08-10T00:00:00Z       1791     1792
# 63  1715-09-01T00:00:00Z       1643     1715
# 64  1830-08-02T00:00:00Z       1824     1830
# 65  1322-01-11T00:00:00Z       1316     1322
# 66  1774-05-10T00:00:00Z       1715     1774
# 67  1824-09-16T00:00:00Z       1815     1824
# 69  1547-04-10T00:00:00Z       1515     1547
# 70  1364-04-16T00:00:00Z       1350     1364
# 72  1108-08-05T00:00:00Z       1060     1108
# 73  0840-06-24T00:00:00Z        814      840
# 74  1285-10-12T00:00:00Z       1270     1285
# 75  1223-07-21T00:00:00Z       1180     1223
# 76  1270-09-01T00:00:00Z       1226     1270
# 77  1574-06-18T00:00:00Z       1573     1574
# 79  1515-01-11T00:00:00Z       1498     1515

# %%
df2.dtypes
# Out:
# nom                   object
# dateOfBirth           object
# placeOfBirthLabel     object
# dateOfDeath           object
# placeOfDeathLabel     object
# placeOfBurialLabel    object
# fatherLabel           object
# motherLabel           object
# spouses               object
# startTime             object
# endTime               object
# startYear              int64
# endYear                int64
# dtype: object

# %%
def which_king(year):
    df_king = df2[df2["startYear"] <= year]
    return df2[df2["startYear"] <= year & df2["endYear"] > year]

# %%
toto = which_king(1222)
toto
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-f71488838bba> in <module>
# ----> 1 toto = which_king(1222)
#       2 toto
#
# <ipython-input-55-812e786056cc> in which_king(year)
#       1 def which_king(year):
# ----> 2     return df2[df2["startYear"] <= year & df2["endYear"] > year]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# 16                     Fontainebleau
# 17                             Creil
# 19             Saint-Germain-en-Laye
# 21                     Fontainebleau
# 30                     Fontainebleau
# 54                     Fontainebleau
# 55                    château de Pau
# 60                           Bourges
# 61             château de Versailles
# 63  château de Saint-Germain-en-Laye
# 64                        Versailles
# 65                         Vincennes
# 66                        Versailles
# 67                        Versailles
# 69                            Cognac
# 70                           Le Mans
# 74                            Poissy
# 75                             Paris
# 76                            Poissy
# 77          château de Fontainebleau
# 79                             Blois
#
#                           placeOfBurialLabel             fatherLabel  \
# 1                      basilique Saint-Denis     Philippe II Auguste
# 3                      basilique Saint-Denis              Charles VI
# 11                     basilique Saint-Denis            François Ier
# 12                     basilique Saint-Denis                Louis XI
# 13                     basilique Saint-Denis     Charles V de France
# 15                     basilique Saint-Denis       Jean II de France
# 16                     basilique Saint-Denis       Charles de Valois
# 17                     basilique Saint-Denis   Philippe IV de France
# 19                     basilique Saint-Denis                Henri II
# 21                     basilique Saint-Denis  Philippe III de France
# 30                     basilique Saint-Denis                Henri II
# 54                     basilique Saint-Denis                Henri IV
# 55                     basilique Saint-Denis      Antoine de Bourbon
# 60             basilique Notre-Dame de Cléry   Charles VII de France
# 61                     basilique Saint-Denis         Louis de France
# 63                     basilique Saint-Denis              Louis XIII
# 64  église de l'Annonciation de Kostanjevica         Louis de France
# 65                     basilique Saint-Denis   Philippe IV de France
# 66                     basilique Saint-Denis         Louis de France
# 67                     basilique Saint-Denis         Louis de France
# 69                     basilique Saint-Denis       Charles d'Orléans
# 70                     basilique Saint-Denis   Philippe VI de France
# 74                     basilique Saint-Denis             Saint Louis
# 75                     basilique Saint-Denis     Louis VII de France
# 76                     basilique Saint-Denis    Louis VIII de France
# 77                     basilique Saint-Denis                Henri II
# 79                     basilique Saint-Denis       Charles d'Orléans
#
#                  motherLabel  \
# 1        Isabelle de Hainaut
# 3         Isabeau de Bavière
# 11          Claude de France
# 12       Charlotte de Savoie
# 13         Jeanne de Bourbon
# 15       Bonne de Luxembourg
# 16        Marguerite d'Anjou
# 17     Jeanne Ire de Navarre
# 19      Catherine de Médicis
# 21         Isabelle d'Aragon
# 30      Catherine de Médicis
# 54          Marie de Médicis
# 55           Jeanne d'Albret
# 60             Marie d'Anjou
# 61     Marie-Josèphe de Saxe
# 63           Anne d'Autriche
# 64     Marie-Josèphe de Saxe
# 65     Jeanne Ire de Navarre
# 66  Marie-Adélaïde de Savoie
# 67     Marie-Josèphe de Saxe
# 69          Louise de Savoie
# 70       Jeanne de Bourgogne
# 74    Marguerite de Provence
# 75        Adèle de Champagne
# 76       Blanche de Castille
# 77      Catherine de Médicis
# 79           Marie de Clèves
#
#                                               spouses             startTime  \
# 1                                 Blanche de Castille  1223-07-21T00:00:00Z
# 3                                       Marie d'Anjou  1422-11-08T00:00:00Z
# 11                               Catherine de Médicis  1547-04-10T00:00:00Z
# 12                                   Anne de Bretagne  1483-09-17T00:00:00Z
# 13                                 Isabeau de Bavière  1380-09-24T00:00:00Z
# 15                                  Jeanne de Bourbon  1364-04-16T00:00:00Z
# 16            Blanche de Navarre, Jeanne de Bourgogne  1328-04-09T00:00:00Z
# 17  Blanche de Bourgogne, Marie de Luxembourg, Jea...  1322-01-11T00:00:00Z
# 19                               Élisabeth d'Autriche  1560-12-25T00:00:00Z
# 21                              Jeanne Ire de Navarre  1285-10-12T00:00:00Z
# 30                                       Marie Stuart  1559-07-30T00:00:00Z
# 54                                    Anne d'Autriche  1610-05-14T00:00:00Z
# 55             Marguerite de France, Marie de Médicis  1572-06-19T00:00:00Z
# 60           Marguerite d'Écosse, Charlotte de Savoie  1461-08-09T00:00:00Z
# 61                                   Marie-Antoinette  1791-09-04T00:00:00Z
# 63      Madame de Maintenon, Marie-Thérèse d'Autriche  1643-05-14T00:00:00Z
# 64                            Marie-Thérèse de Savoie  1824-09-16T00:00:00Z
# 65                                Jeanne de Bourgogne  1316-11-27T00:00:00Z
# 66                                  Marie Leszczyńska  1715-09-01T00:00:00Z
# 67                          Marie-Joséphine de Savoie  1815-07-08T00:00:00Z
# 69            Éléonore de Habsbourg, Claude de France  1515-01-11T00:00:00Z
# 70         Jeanne Ire d'Auvergne, Bonne de Luxembourg  1350-08-30T00:00:00Z
# 74                Isabelle d'Aragon, Marie de Brabant  1270-09-01T00:00:00Z
# 75  Agnès de Méranie, Isabelle de Hainaut, Ingebur...  1180-09-25T00:00:00Z
# 76                             Marguerite de Provence  1226-11-15T00:00:00Z
# 77                                 Louise de Lorraine  1573-05-11T00:00:00Z
# 79  Marie d'Angleterre, Jeanne de France, Anne de ...  1498-04-25T00:00:00Z
#
#                  endTime  startYear  endYear
# 1   1226-11-15T00:00:00Z       1223     1226
# 3   1461-08-09T00:00:00Z       1422     1461
# 11  1559-07-20T00:00:00Z       1547     1559
# 12  1498-04-25T00:00:00Z       1483     1498
# 13  1422-10-30T00:00:00Z       1380     1422
# 15  1380-09-24T00:00:00Z       1364     1380
# 16  1350-08-30T00:00:00Z       1328     1350
# 17  1328-02-09T00:00:00Z       1322     1328
# 19  1574-06-19T00:00:00Z       1560     1574
# 21  1314-12-07T00:00:00Z       1285     1314
# 30  1560-12-25T00:00:00Z       1559     1560
# 54  1643-05-14T00:00:00Z       1610     1643
# 55  1610-05-14T00:00:00Z       1572     1610
# 60  1483-09-17T00:00:00Z       1461     1483
# 61  1792-08-10T00:00:00Z       1791     1792
# 63  1715-09-01T00:00:00Z       1643     1715
# 64  1830-08-02T00:00:00Z       1824     1830
# 65  1322-01-11T00:00:00Z       1316     1322
# 66  1774-05-10T00:00:00Z       1715     1774
# 67  1824-09-16T00:00:00Z       1815     1824
# 69  1547-04-10T00:00:00Z       1515     1547
# 70  1364-04-16T00:00:00Z       1350     1364
# 74  1285-10-12T00:00:00Z       1270     1285
# 75  1223-07-21T00:00:00Z       1180     1223
# 76  1270-09-01T00:00:00Z       1226     1270
# 77  1574-06-18T00:00:00Z       1573     1574
# 79  1515-01-11T00:00:00Z       1498     1515

# %% [markdown]
# ### 2) Save in csv

# %%
df.to_csv("rois-france.csv")
